# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
#
# This notebook performs basic exploratory data analysis on the cleaned dataset: `outputs/cleaned_data.csv`.
#
# - Dataset source: cleaned by `clean_data.py`
# - Goal: understand distributions, missing values, outliers, and overall structure

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

sns.set(style="whitegrid")

# Load cleaned data
df = pd.read_csv("../outputs/cleaned_data.csv")
df.head()
# Out:
#           Name                    Email  Age         Country  SignUpDate  \
# 0     John Doe     john.doe@example.com   29   United States  2023-01-15
# 1   Jane Smith                      NaN   29   United States         NaN
# 2  Emily White  emily.white@example.com   22  United Kingdom         NaN
# 3   Lucas Grey                      NaN   34          Mexico  2021-11-22
# 4   Anna Black                      NaN   28         Germany  2022-05-05
#
#    Income    Status
# 0    5000    Active
# 1    4000    Active
# 2    3500    Active
# 3    5200   Unknown
# 4    3200  Inactive

# %% [markdown]
# ## 🔍 Basic Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        28 non-null     object
#  1   Email       16 non-null     object
#  2   Age         28 non-null     int64
#  3   Country     28 non-null     object
#  4   SignUpDate  18 non-null     object
#  5   Income      28 non-null     int64
#  6   Status      28 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 1.7+ KB

# %%
df.describe(include="all")
# Out:
#               Name                   Email        Age        Country  \
# count           28                      16  28.000000             28
# unique          10                       7        NaN              6
# top     Jane Smith  nina.brown@example.com        NaN  United States
# freq             5                       4        NaN             11
# mean           NaN                     NaN  29.821429            NaN
# std            NaN                     NaN   4.000496            NaN
# min            NaN                     NaN  22.000000            NaN
# 25%            NaN                     NaN  28.000000            NaN
# 50%            NaN                     NaN  29.000000            NaN
# 75%            NaN                     NaN  31.000000            NaN
# max            NaN                     NaN  41.000000            NaN
#
#         SignUpDate       Income  Status
# count           18    28.000000      28
# unique          14          NaN       3
# top     2022-05-05          NaN  Active
# freq             3          NaN      15
# mean           NaN  4328.607143     NaN
# std            NaN   973.300735     NaN
# min            NaN  3000.000000     NaN
# 25%            NaN  3450.000000     NaN
# 50%            NaN  4100.000000     NaN
# 75%            NaN  5050.000000     NaN
# max            NaN  6200.000000     NaN

# %% [markdown]
# ## 📉 Missing Values Visualization

# %%
msno.matrix(df, figsize=(10, 4))
plt.title("Missing Data Overview")
plt.show()

# %% [markdown]
# ## 📌 Categorical Distributions

# %%
sns.countplot(data=df, x="Status")
plt.title("User Status Distribution")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(data=df, x="Country")
plt.title("Country Distribution")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## 📊 Numerical Distributions

# %%
sns.histplot(df["Age"], bins=10, kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(df["Income"], bins=10, kde=True)
plt.title("Income Distribution")
plt.show()

# %% [markdown]
# ## 📎 Income by Country

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="Country", y="Income")
plt.title("Income Distribution by Country")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## ✅ Summary
# - The dataset is clean with minor missing values (e.g., Email, SignUpDate)
# - Age is normally distributed around ~29 years
# - Income varies between users and countries
# - Status is mostly 'Active', followed by 'Inactive' and 'Unknown'
#
# This notebook gives a solid understanding of the dataset and can be expanded for feature engineering or business insights.
